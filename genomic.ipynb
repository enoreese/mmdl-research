# %%
import pandas as pd
import numpy as np

# %%
clinical = pd.read_csv("Data/data/dataframes/clin_df.csv")

# %%
clinical.sample(5)
# Out:
#      duration.OS  observed.OS  duration.PFS observed.PFS  \
# 280    26.663004        False           NaN          NaN
# 108    37.742452         True     15.221912         True
# 372     6.246573        False      6.246573        False
# 137    23.934238         True      9.435613         True
# 75     56.843814        False     27.583551        False
#
#     Complete gross resection Received PARPi stage Type of surgery        age  \
# 280                     True           True   III        NACT-IDS  75.761807
# 108                    False          False   III        NACT-IDS  69.527721
# 372                      NaN            NaN   III             NaN  61.000000
# 137                     True          False    IV        NACT-IDS  62.631075
# 75                      True          False   III        NACT-IDS  58.803559
#
#        Patient ID Data split adnexal_lesion omental_lesion
# 280           281   Training           True           True
# ...

# %%
clinical.shape
# Out:
# (444, 13)

# %%
clinical.columns
# Out:
# Index(['duration.OS', 'observed.OS', 'duration.PFS', 'observed.PFS',
#        'Complete gross resection', 'Received PARPi', 'stage',
#        'Type of surgery', 'age', 'Patient ID', 'Data split', 'adnexal_lesion',
#        'omental_lesion'],
#       dtype='object')

# %%
genomic = pd.read_csv("Data/data/dataframes/genomic_df.csv")
genomic.shape
# Out:
# (383, 29)

# %%
genomic.sample(5)
# Out:
#     HRD status   ATM  BAP1 BARD1   BLM BRCA1 BRCA2 BRIP1 CHEK1 CHEK2  ...  \
# 344        HRP  None  None  None  None  None  None  None  None  None  ...
# 95         HRP  None  None  None  None  None  None  None  None  None  ...
# 87         HRP  None  None  None  None  None  None  None  None  None  ...
# 118        HRP  None  None  None  None  None  None  None  None  None  ...
# 74         HRP  None  None  None  None  None  None  None  None  None  ...
#
#      MDC1 RAD51C   ATR CDK12 CCNE1 TP53 Sig. 3        Seq. Dataset  \
# 344  None   None  None  None  None  SNV    Low         WES    TCGA
# 95   None   None  None  None  Amp.  SNV    NaN  MSK-IMPACT   MSKCC
# 87   None   None  None  None  Amp.  SNV    NaN  MSK-IMPACT   MSKCC
# 118  None   None  None  None  None  SNV    NaN  MSK-IMPACT   MSKCC
# 74   None   None  None  None  None  SNV    NaN  MSK-IMPACT   MSKCC
#
#        Patient ID
# 344  TCGA-24-1427
# 95            113
# 87            260
# 118           136
# 74            104
# ...

# %%
genomic.columns
# Out:
# Index(['HRD status', 'ATM', 'BAP1', 'BARD1', 'BLM', 'BRCA1', 'BRCA2', 'BRIP1',
#        'CHEK1', 'CHEK2', 'FANCA', 'FANCC', 'MRE11', 'NBN', 'PALB2', 'RAD50',
#        'RAD51', 'RAD51B', 'RAD51D', 'MDC1', 'RAD51C', 'ATR', 'CDK12', 'CCNE1',
#        'TP53', 'Sig. 3', 'Seq.', 'Dataset', 'Patient ID'],
#       dtype='object')

# %%
crs = pd.read_csv("Data/data/dataframes/train_ids.csv")
crs.shape
# Out:
# (404, 1)

# %%
crs.head()
# Out:
#   Patient ID
# 0        001
# 1        002
# 2        003
# 3        004
# 4        005

# %%
genomic[genomic['BRCA1']!='None']
# Out:
#     HRD status   ATM  BAP1 BARD1   BLM BRCA1 BRCA2 BRIP1      CHEK1 CHEK2  \
# 7          HRD  None  None  None  None   SNV  None  None       None  None
# 13         HRD  None  None  None  None   SNV  None  None       None  None
# 15         HRD  None  None  None  None   SNV  None  None       None  None
# 26         HRD  None  None  None  None   SNV  None  None       None  None
# 31         HRD  None  None  None  None   SNV  None  None       None  None
# 35         HRD  None  None  None  None   SNV  None  None       None  None
# 37         HRD  None  None  None  None   SNV  None  None       None  None
# 64         HRD  None  None  None  None   SNV  None  None       None  None
# 84         HRD  None  None  None  None   SNV  None  None       None  None
# 85         HRD  None  None  None  None   SNV  None  None       None  None
# 93         HRD  None  None  None  None   SNV  None  None       None  None
# 98         HRD  None  None  None  None   SNV  None  None       None  None
# ...

# %%
genomic['BRCA1'].value_counts()
# Out:
# None    325
# SNV      58
# Name: BRCA1, dtype: int64
